# %%
import pandas as pd
import numpy as np
import json
from datetime import datetime

# %%
dict={
    "name":['sanketh','elon','Musk'],
   "age":[22,33,44],
#     "age":["22","33","43"],
    "place":["India","US","South africa"]

}

# %%
df=pd.DataFrame(dict)

# %%
print(df)
# Out:
#       name age         place
# 0  sanketh  22         India
# 1     elon  33            US
# 2     Musk  43  South africa

# %%
df.to_csv("sample.csv")

# %%
df.to_csv("sample_index.csv",index=False)

# %%
df.head(2)
# Out:
#       name age  place
# 0  sanketh  22  India
# 1     elon  33     US

# %%
df
# Out:
#       name age         place
# 0  sanketh  22         India
# 1     elon  33            US
# 2     Musk  43  South africa

# %%
df.tail(2)
# Out:
#    name age         place
# 1  elon  33            US
# 2  Musk  43  South africa

# %%
df.describe()
# Out:
#         name age  place
# count      3   3      3
# unique     3   3      3
# top     elon  43  India
# freq       1   1      1

# %%
df.describe()
# Out:
#         name age  place
# count      3   3      3
# unique     3   3      3
# top     elon  43  India
# freq       1   1      1

# %%
file=pd.read_csv("sample_index.csv")

# %%
file
# Out:
#       name  age         place
# 0  sanketh   22         India
# 1     elon   33            US
# 2     Musk   43  South africa

# %%
file["name"]
# Out:
# 0    sanketh
# 1       elon
# 2       Musk
# Name: name, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["age"])
# Out:
# pandas.core.series.Series

# %%
new_df=pd.DataFrame(np.random.rand(5,5))# creates a 5 * 5 2D array with random values

# %%
new_df
# Out:
#           0         1         2         3         4
# 0  0.581892  0.149054  0.228563  0.584198  0.336556
# 1  0.549370  0.258746  0.123919  0.940273  0.086750
# 2  0.883568  0.569229  0.260839  0.086753  0.536075
# 3  0.395023  0.797556  0.516157  0.052350  0.391898
# 4  0.855209  0.362135  0.165120  0.450976  0.332894

# %%
new_df.describe()
# Out:
#               0         1         2         3         4
# count  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   0.653012  0.427344  0.258919  0.422910  0.336834
# std    0.209998  0.258511  0.153395  0.369047  0.162239
# min    0.395023  0.149054  0.123919  0.052350  0.086750
# 25%    0.549370  0.258746  0.165120  0.086753  0.332894
# 50%    0.581892  0.362135  0.228563  0.450976  0.336556
# 75%    0.855209  0.569229  0.260839  0.584198  0.391898
# max    0.883568  0.797556  0.516157  0.940273  0.536075

# %%
new_df[0][0]=1

# %%
new_df
# Out:
#           0         1         2         3         4
# 0  1.000000  0.149054  0.228563  0.584198  0.336556
# 1  0.549370  0.258746  0.123919  0.940273  0.086750
# 2  0.883568  0.569229  0.260839  0.086753  0.536075
# 3  0.395023  0.797556  0.516157  0.052350  0.391898
# 4  0.855209  0.362135  0.165120  0.450976  0.332894

# %%
for i in range(5):
    new_df[1][i]=i

# %%
new_df
# Out:
#           0    1         2         3         4
# 0  1.000000  0.0  0.228563  0.584198  0.336556
# 1  0.549370  1.0  0.123919  0.940273  0.086750
# 2  0.883568  2.0  0.260839  0.086753  0.536075
# 3  0.395023  3.0  0.516157  0.052350  0.391898
# 4  0.855209  4.0  0.165120  0.450976  0.332894

# %%
for i,j in range(5):
    new_df[i][j]=i
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-d76aab2466f6> in <module>
# ----> 1 for i,j in range(5):
#       2     new_df[i][j]=i
#
# TypeError: cannot unpack non-iterable int object

# %%
new_df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
file=open("option_chain5.json")

# %%
data=file.read()

# %%
nifty_data=json.loads(data)
ce_values= [value["CE"] for value in nifty_data["filtered"]["data"] ]
pe_values= [value["PE"] for value in nifty_data["filtered"]["data"] ]
ce=pd.DataFrame(ce_values).sort_values("strikePrice")
pe=pd.DataFrame(pe_values).sort_values("strikePrice")

# %%
ce.head()
# Out:
#    askPrice  askQty  bidQty  bidprice  change  changeinOpenInterest  \
# 0   2157.05     975     975   2067.65     0.0                     0
# 1   2158.80    7350    7350   1930.00     0.0                     0
# 2   2067.50     975    7350   1882.45     0.0                     0
# 3   2149.65    7350    7350   1835.15     0.0                     0
# 4   1967.50     975    7350   1721.75     0.0                     0
#
#     expiryDate                      identifier  impliedVolatility  lastPrice  \
# 0  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9300.00                  0    1802.75
# 1  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9350.00                  0       0.00
# 2  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9400.00                  0       0.00
# 3  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9450.00                  0       0.00
# 4  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9500.00                  0    1692.75
#
#    openInterest  pChange  pchangeinOpenInterest  strikePrice  \
# ...

# %%
ce["type"]="CE" # creates a new column type with values as CE

# %%
ce.head()
# Out:
#    askPrice  askQty  bidQty  bidprice  change  changeinOpenInterest  \
# 0   2157.05     975     975   2067.65     0.0                     0
# 1   2158.80    7350    7350   1930.00     0.0                     0
# 2   2067.50     975    7350   1882.45     0.0                     0
# 3   2149.65    7350    7350   1835.15     0.0                     0
# 4   1967.50     975    7350   1721.75     0.0                     0
#
#     expiryDate                      identifier  impliedVolatility  lastPrice  \
# 0  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9300.00                  0    1802.75
# 1  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9350.00                  0       0.00
# 2  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9400.00                  0       0.00
# 3  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9450.00                  0       0.00
# 4  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9500.00                  0    1692.75
#
#    openInterest  pChange  pchangeinOpenInterest  strikePrice  \
# ...

# %%
ce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 0 to 77
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   askPrice               78 non-null     float64
#  1   askQty                 78 non-null     int64
#  2   bidQty                 78 non-null     int64
#  3   bidprice               78 non-null     float64
#  4   change                 78 non-null     float64
#  5   changeinOpenInterest   78 non-null     int64
#  6   expiryDate             78 non-null     object
#  7   identifier             78 non-null     object
#  8   impliedVolatility      78 non-null     int64
#  9   lastPrice              78 non-null     float64
#  10  openInterest           78 non-null     int64
#  11  pChange                78 non-null     float64
#  12  pchangeinOpenInterest  78 non-null     float64
#  13  strikePrice            78 non-null     int64
# ...

# %%
ce[["change",   "changeinOpenInterest", "impliedVolatility",    "lastPrice",    "openInterest", "pChange",  "pchangeinOpenInterest",    "strikePrice","type"]].head(
)
# Out:
#    change  changeinOpenInterest  impliedVolatility  lastPrice  openInterest  \
# 0     0.0                     0                  0    1802.75             1
# 1     0.0                     0                  0       0.00             0
# 2     0.0                     0                  0       0.00             0
# 3     0.0                     0                  0       0.00             0
# 4     0.0                     0                  0    1692.75             4
#
#    pChange  pchangeinOpenInterest  strikePrice type
# 0      0.0                    0.0         9300   CE
# 1      0.0                    0.0         9350   CE
# 2      0.0                    0.0         9400   CE
# 3      0.0                    0.0         9450   CE
# 4      0.0                    0.0         9500   CE

# %%
pe["type"]="PE"

# %%
pe.head()
# Out:
#    askPrice  askQty  bidQty  bidprice  change  changeinOpenInterest  \
# 0      0.05   14400       0       0.0   -0.25                   287
# 1      0.05     375       0       0.0   -0.45                   103
# 2      0.05   11325       0       0.0   -0.40                  -105
# 3      0.10    1500       0       0.0   -0.40                    -1
# 4      0.05   22200       0       0.0   -0.35                 -1532
#
#     expiryDate                      identifier  impliedVolatility  lastPrice  \
# 0  01-Oct-2020  OPTIDXNIFTY01-10-2020PE9300.00                  0       0.05
# 1  01-Oct-2020  OPTIDXNIFTY01-10-2020PE9350.00                  0       0.05
# 2  01-Oct-2020  OPTIDXNIFTY01-10-2020PE9400.00                  0       0.05
# 3  01-Oct-2020  OPTIDXNIFTY01-10-2020PE9450.00                  0       0.05
# 4  01-Oct-2020  OPTIDXNIFTY01-10-2020PE9500.00                  0       0.05
#
#    openInterest    pChange  pchangeinOpenInterest  strikePrice  \
# ...

# %%
pe[["change",	"changeinOpenInterest",	"impliedVolatility",	"lastPrice",	"openInterest",	"pChange",	"pchangeinOpenInterest",	"strikePrice","type"]].head(
)
# Out:
#    change  changeinOpenInterest  impliedVolatility  lastPrice  openInterest  \
# 0   -0.25                   287                  0       0.05          1687
# 1   -0.45                   103                  0       0.05           229
# 2   -0.40                  -105                  0       0.05           491
# 3   -0.40                    -1                  0       0.05            30
# 4   -0.35                 -1532                  0       0.05          5197
#
#      pChange  pchangeinOpenInterest  strikePrice type
# 0 -83.333333              20.500000         9300   PE
# 1 -90.000000              81.746032         9350   PE
# 2 -88.888889             -17.617450         9400   PE
# 3 -88.888889              -3.225806         9450   PE
# 4 -87.500000             -22.767127         9500   PE

# %%
pe["type"]="PE"

# %%
pe[["change",	"changeinOpenInterest",	"impliedVolatility",	"lastPrice",	"openInterest",	"pChange",	"pchangeinOpenInterest",	"strikePrice","type"]].head(
)
# Out:
#    change  changeinOpenInterest  impliedVolatility  lastPrice  openInterest  \
# 0   -0.25                   287                  0       0.05          1687
# 1   -0.45                   103                  0       0.05           229
# 2   -0.40                  -105                  0       0.05           491
# 3   -0.40                    -1                  0       0.05            30
# 4   -0.35                 -1532                  0       0.05          5197
#
#      pChange  pchangeinOpenInterest  strikePrice type
# 0 -83.333333              20.500000         9300   PE
# 1 -90.000000              81.746032         9350   PE
# 2 -88.888889             -17.617450         9400   PE
# 3 -88.888889              -3.225806         9450   PE
# 4 -87.500000             -22.767127         9500   PE

# %%
ce.head()
# Out:
#    askPrice  askQty  bidQty  bidprice  change  changeinOpenInterest  \
# 0   2157.05     975     975   2067.65     0.0                     0
# 1   2158.80    7350    7350   1930.00     0.0                     0
# 2   2067.50     975    7350   1882.45     0.0                     0
# 3   2149.65    7350    7350   1835.15     0.0                     0
# 4   1967.50     975    7350   1721.75     0.0                     0
#
#     expiryDate                      identifier  impliedVolatility  lastPrice  \
# 0  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9300.00                  0    1802.75
# 1  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9350.00                  0       0.00
# 2  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9400.00                  0       0.00
# 3  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9450.00                  0       0.00
# 4  01-Oct-2020  OPTIDXNIFTY01-10-2020CE9500.00                  0    1692.75
#
#    openInterest  pChange  pchangeinOpenInterest  strikePrice  \
# ...

# %%
ce_new=ce[["change",	"changeinOpenInterest",	"impliedVolatility",	"lastPrice",	"openInterest",	"pChange",	"pchangeinOpenInterest",	"strikePrice","type"]].copy(
)

# %%
ce_new.head()
# Out:
#    change  changeinOpenInterest  impliedVolatility  lastPrice  openInterest  \
# 0     0.0                     0                  0    1802.75             1
# 1     0.0                     0                  0       0.00             0
# 2     0.0                     0                  0       0.00             0
# 3     0.0                     0                  0       0.00             0
# 4     0.0                     0                  0    1692.75             4
#
#    pChange  pchangeinOpenInterest  strikePrice type
# 0      0.0                    0.0         9300   CE
# 1      0.0                    0.0         9350   CE
# 2      0.0                    0.0         9400   CE
# 3      0.0                    0.0         9450   CE
# 4      0.0                    0.0         9500   CE

# %%
pe_new=pe[["change",	"changeinOpenInterest",	"impliedVolatility",	"lastPrice",	"openInterest",	"pChange",	"pchangeinOpenInterest",	"strikePrice","type"]].copy(
)

# %%
frames=[ce_new,pe_new]

# %%
df1=pd.concat(frames)

# %%
df1.head()
# Out:
#    change  changeinOpenInterest  impliedVolatility  lastPrice  openInterest  \
# 0     0.0                     0                  0    1802.75             1
# 1     0.0                     0                  0       0.00             0
# 2     0.0                     0                  0       0.00             0
# 3     0.0                     0                  0       0.00             0
# 4     0.0                     0                  0    1692.75             4
#
#    pChange  pchangeinOpenInterest  strikePrice type
# 0      0.0                    0.0         9300   CE
# 1      0.0                    0.0         9350   CE
# 2      0.0                    0.0         9400   CE
# 3      0.0                    0.0         9450   CE
# 4      0.0                    0.0         9500   CE

# %%
df1
# Out:
#     change  changeinOpenInterest  impliedVolatility  lastPrice  openInterest  \
# 0     0.00                     0                  0    1802.75             1
# 1     0.00                     0                  0       0.00             0
# 2     0.00                     0                  0       0.00             0
# 3     0.00                     0                  0       0.00             0
# 4     0.00                     0                  0    1692.75             4
# ..     ...                   ...                ...        ...           ...
# 73    0.00                     0                  0       0.00             0
# 74    0.00                     0                  0    2070.40             1
# 75  221.35                     0                  0    1670.25             2
# 76    0.00                     0                  0       0.00             0
# 77    0.00                     0                  0       0.00             0
#
# ...

# %%
df1.to_dict('records')#converts dataframes into a list of dictionaries
# Out:
# [{'change': 0.0,
#   'changeinOpenInterest': 0,
#   'impliedVolatility': 0,
#   'lastPrice': 1802.75,
#   'openInterest': 1,
#   'pChange': 0.0,
#   'pchangeinOpenInterest': 0.0,
#   'strikePrice': 9300,
#   'type': 'CE'},
#  {'change': 0.0,
#   'changeinOpenInterest': 0,
#   'impliedVolatility': 0,
#   'lastPrice': 0.0,
#   'openInterest': 0,
#   'pChange': 0.0,
#   'pchangeinOpenInterest': 0.0,
#   'strikePrice': 9350,
#   'type': 'CE'},
#  {'change': 0.0,
#   'changeinOpenInterest': 0,
#   'impliedVolatility': 0,
#   'lastPrice': 0.0,
#   'openInterest': 0,
#   'pChange': 0.0,
#   'pchangeinOpenInterest': 0.0,
#   'strikePrice': 9400,
#   'type': 'CE'},
#  {'change': 0.0,
#   'changeinOpenInterest': 0,
#   'impliedVolatility': 0,
#   'lastPrice': 0.0,
#   'openInterest': 0,
#   'pChange': 0.0,
#   'pchangeinOpenInterest': 0.0,
#   'strikePrice': 9450,
#   'type': 'CE'},
#  {'change': 0.0,
#   'changeinOpenInterest': 0,
#   'impliedVolatility': 0,
#   'lastPrice': 1692.75,
# ...

# %%
df_list=[]

# %%
df1["Time"]=datetime.now().strftime("%H:%M")

# %%
df1.head()
# Out:
#    change  changeinOpenInterest  impliedVolatility  lastPrice  openInterest  \
# 0     0.0                     0                  0    1802.75             1
# 1     0.0                     0                  0       0.00             0
# 2     0.0                     0                  0       0.00             0
# 3     0.0                     0                  0       0.00             0
# 4     0.0                     0                  0    1692.75             4
#
#    pChange  pchangeinOpenInterest  strikePrice type   Time
# 0      0.0                    0.0         9300   CE  19:42
# 1      0.0                    0.0         9350   CE  19:42
# 2      0.0                    0.0         9400   CE  19:42
# 3      0.0                    0.0         9450   CE  19:42
# 4      0.0                    0.0         9500   CE  19:42

# %%
df1.tail()
# Out:
#     change  changeinOpenInterest  impliedVolatility  lastPrice  openInterest  \
# 73    0.00                     0                  0       0.00             0
# 74    0.00                     0                  0    2070.40             1
# 75  221.35                     0                  0    1670.25             2
# 76    0.00                     0                  0       0.00             0
# 77    0.00                     0                  0       0.00             0
#
#       pChange  pchangeinOpenInterest  strikePrice type   Time
# 73   0.000000                    0.0        12950   PE  19:42
# 74   0.000000                    0.0        13000   PE  19:42
# 75  15.277107                    0.0        13050   PE  19:42
# 76   0.000000                    0.0        13100   PE  19:42
# 77   0.000000                    0.0        13150   PE  19:42

# %%
df_list.append(df1.to_dict('records'))#converts dataframes into a list of dictionaries

# %%
df_list
# Out:
# [[{'change': 0.0,
#    'changeinOpenInterest': 0,
#    'impliedVolatility': 0,
#    'lastPrice': 1802.75,
#    'openInterest': 1,
#    'pChange': 0.0,
#    'pchangeinOpenInterest': 0.0,
#    'strikePrice': 9300,
#    'type': 'CE',
#    'Time': '19:42'},
#   {'change': 0.0,
#    'changeinOpenInterest': 0,
#    'impliedVolatility': 0,
#    'lastPrice': 0.0,
#    'openInterest': 0,
#    'pChange': 0.0,
#    'pchangeinOpenInterest': 0.0,
#    'strikePrice': 9350,
#    'type': 'CE',
#    'Time': '19:42'},
#   {'change': 0.0,
#    'changeinOpenInterest': 0,
#    'impliedVolatility': 0,
#    'lastPrice': 0.0,
#    'openInterest': 0,
#    'pChange': 0.0,
#    'pchangeinOpenInterest': 0.0,
#    'strikePrice': 9400,
#    'type': 'CE',
#    'Time': '19:42'},
#   {'change': 0.0,
#    'changeinOpenInterest': 0,
#    'impliedVolatility': 0,
#    'lastPrice': 0.0,
#    'openInterest': 0,
#    'pChange': 0.0,
#    'pchangeinOpenInterest': 0.0,
#    'strikePrice': 9450,
#    'type': 'CE',
# ...

# %%
with open("test_data.json","a") as f:
    f.write(json.dumps(df_list,indent=4,sort_keys=True))

# %%
len(df_list[-1])
# Out:
# 156

# %%
len(df_list[0])
# Out:
# 156

# %%
df_list[-1][0]["Time"]
# Out:
# '19:42'

# %%
len(df_list[-1][0]["Time"])
# Out:
# 5
